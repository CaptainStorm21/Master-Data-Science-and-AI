# %% [markdown]
# <a href="https://colab.research.google.com/github/CaptainStorm21/Master-Data-Science-and-AI/blob/main/chapter1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
a = 6

# %%
print (a)
# Out:
# 6

# %%
import pandas as pd
df = pd.read_csv('sample_data/dataset.csv')

# %%
df.head()
# Out:
#                                        hospital_name      gender   color  \
# 0                           BAPTIST HOSPITAL HOME RX        Male    Puce
# 1                      LENOIR MEMORIAL HOSPITAL INC.        Male   Green
# 2                       LAWRENCE & MEMORIAL HOSPITAL        Male  Violet
# 3  STATE OF MISSISSIPPI - UNIVERSITY OF MISSISSIP...        Male     Red
# 4                             SOUTHSIDE HOSPITAL HHA  Polygender  Fuscia
#
#                       job_title          ssn  birthdate            race  \
# 0              Dental Hygienist  841-01-1423  2/15/1955  South American
# 1  Human Resources Assistant II  582-59-0411   7/7/1987     Costa Rican
# 2              Data Coordinator  618-03-2177  2/15/1994          Ottawa
# 3               Design Engineer  277-62-4046  3/19/1982          Pueblo
# 4              Junior Executive  314-59-8366   7/5/1989          Ottawa
#
#   shirt_size  phone_number                 email_address
# ...
